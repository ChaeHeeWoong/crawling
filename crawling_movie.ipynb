# %%
import numpy as np
import pandas as pd
import requests as rq #url을 가져오기 위한 파이썬 내장 패키지

from bs4 import BeautifulSoup

# %%
url = rq.get('https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=187940&target=after' )
#영화 백두산 평점 리스트 사이트 주소
print(url) #Response[200]이 출력되면 성공적으로 사이트를 가져옴
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(url.text, 'lxml')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="me2:image"/>
# <meta content="네이버영화 " property="me2:post_tag"/>
# <meta content="네이버영화" property="me2:category1"/>
# <meta content="" property="me2:category2"/>
# <meta content="평점 : 네이버 영화" property="og:title"/>
# <meta content="네티즌 평점과 리뷰 정보 제공" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="https://movie.naver.com/movie/point/af/list.nhn?st=mcode&amp;sword=187940&amp;target=after" property="og:url"/>
# <meta content="http://static.naver.net/m/movie/icons/OG_270_270.png" property="og:image"/><!-- http://static.naver.net/m/movie/im/navermovie.jpg -->
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="og:article:thumbnailUrl"/>
# ...

# %%
import re
score_list = []
def croll_score() :
    for score in soup.find_all('div','list_netizen_score'):
        score_list.append(int(re.findall('\d+', str(score.get_text))[2]))

# %%
croll_score()
print(score_list)
# Out:
# [4, 1, 4, 9, 2, 10, 1, 10, 8, 10]

# %%
review_list = []
for review in soup.find_all('td','title'):
    review_list.append(review.get_text().split('\n')[5])

# %%
review_list
# Out:
# ['배우들의 연기력이 돋보이는 여운이 남는 작풉이었습니다. ',
#  '이게 이정도로 별로였나???  이상하네요~ 평점들이 모두 최악이네..ㅠㅠ 어제 애들데리고 우리 4 식구 봤었는데...이렇게 욕먹을 정도로 재미없었지는 않았던거 같고요(물론 개인차^^) 그렇다고 나도 딱히 높은 평점을 주는 사람은 아닌데도.. 그래도 나름 볼만했는데요~^^ 특히 이병헌의 연기는 정말...갠적으로 대한민국에서 탑이라고 감히 얘기하고 싶네요~ 이병헌 배우 사람자체를 좋아하는건 아니지만..연기하나 만큼은 부정하지 못할듯... ',
#  '나름 잼나게 봣어요 ',
#  '한국과 미국을 쓰레기로 만들고 북한을 미화하네? 적화통일용 빨갱이 영화냐? ',
#  '역시 이병헌님은 믿고보는 배우입니다! ',
#  '한국영화 진짜 많이 발전했네요. 간만에 극장서 영화 잘 봤습니다^^ ',
#  '그닥..별로에요.. ',
#  '재난영화답게 스펙터클한 영상 약간의 신파 코믹 등을 잘 버무린 영화로 보입니다. ',
#  '음식 영화도 아닌데 왜 침이 고이냐ㅋㅋ그래서 레몬사탕 어디껀가요? ',
#  '이것도 영화라고  돈이 아깝다 ']
